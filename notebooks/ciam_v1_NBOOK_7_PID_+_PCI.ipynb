# %%
# %pip install --quiet pydantic chromadb langchain langchain_experimental langchain_openai langchain_community
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import json

product_path = Path("../initial-training-sets/datasets/dataset_products.json")
product_images_path = Path("../initial-training-sets/datasets/images/")
product_data = json.loads(product_path.read_text())

from datetime import date
from uuid import UUID
from pydantic import BaseModel
from typing import List

class RawReview(BaseModel):
    id: UUID
    review_ref: str
    product_id: UUID
    review_content: str
    review_title: str
    date_written: date
    product_asin: str
    helpful_count: int
    rating_given: int
    review_page_url: str

class RAWProduct(BaseModel):
    id: UUID
    name: str
    description: str
    product_asin: str
    overall_ratings: float
    total_customers_that_rated: int
    price: float
    currency: str
    category: str
    sub_category: str
    product_page_url: str
    image_url: str
    reviews: List[RawReview]
    

from langchain_core.documents import Document

class ProductCombinedInformation:
    
    product: RAWProduct
    
    def __init__(self, product: RAWProduct) -> None:
        self.product = product
        
    def get_document(self):
        return Document(page_content=self.info(), id=str(self.product.id), metadata={
            "product_id": self.product.id,
            "product_asin": self.product.product_asin,
            "image_url": self.product.image_url,
            "name": self.product.name
        })
    
    
    def info(self):
        return (
            f"Product ID: {str(self.product.id).strip()} \n"
            f"Product Name: {str(self.product.name).strip()} \n"
            f"Product Description: {str(self.product.description).strip()} \n"
            f"Product Asin: {self.product.product_asin} \n"
            f"Overall Ratings {self.product.overall_ratings} \n"
            f"Total Customers that rated: {self.product.total_customers_that_rated} \n"
            f"Pric: {self.product.currency}{self.product.price} \n"   
        )
        
    def image_path(self):
        return f"{product_images_path}/{self.product.product_asin}.png"

# %%
product_summary_model_name = "llama3.1"
image_description_model_name = "llava"

# product_summary_model_name = "gpt-4o"
# image_description_model_name = "gpt-4o"
# text_embedding_model_name = ""

# %% [markdown]
# ### PID: Product Image Description

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_community.chat_models import ChatOllama
from PIL import Image
from IPython.display import HTML, display
import base64

def encode_image(image_path: str):
    """Returns the base64 string for the image"""
    
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

def describe_image(img_base64, prompt, model_name: str, image_format: str = "png"):
        
    
    """
    Describes the image provided. The prompt is used to guide the model on what
    to do with the description and what it should do.

    Raises:
        ValueError: If the wrong model name is provided.
        Exception: If any error occur

    Returns:
        str: The description generated for the image
    """
    
    if model_name not in [ "llava", "gpt-4o" ]:
        raise ValueError("Please provide either llava or gpt-4o")
    
    image_url = f"data:image/{image_format};base64,{img_base64}"
    
    if model_name == "gpt-4o":
        chat = ChatOpenAI(model=model_name, max_tokens=1024, temperature=0)
        msg = chat.invoke([
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_url
                        }
                    }
                ]
            )
        ])
    elif model_name == "llava":
        chat = ChatOllama(model=model_name, num_ctx=1024)
        msg = chat.invoke([
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_url
                        }
                    }
                ]
            )
        ])
    else:
        raise Exception("Unknown model name.")
        
    return msg.content


def plt_img_base64(img_base64):
  """Display base64 encoded string as image"""

  # Create an HTML img tag with the base64 string as the source
  image_html = f'<img width="200px" height="200px" src="data:image/jpeg;base64,{img_base64}" />'
  display(HTML(image_html))

# %% [markdown]
# ### PCI: Product Combined Info

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain.prompts import ChatPromptTemplate
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

def summarise_product_info(product_info: str, model_name: str):
    
    if model_name not in [ "llava", "gpt-4o", "llama3", "llama3.1", "phi3", "mistral" ]:
        raise ValueError("Please provide either llava or gpt-4o")
    
    prompt_template = ("You are an assistant tasked with summarizing tables and "
                    "text for retrieval. These summaries will be embedded and used " 
                    "to retrieve the raw text. Give a concise summary of the product. "
                    "Ensure you include important details "
                    "that is well optimized for retrieval.\n"
                    f"Product: {product_info}\n"
                    "Your response should start with the product name."
                    )
    
    prompt = ChatPromptTemplate.from_template(prompt_template)
    
    if model_name == "gpt-4o":
        model = ChatOpenAI(model=model_name, max_tokens=1024, temperature=0)
    else:
        model = ChatOllama(model=model_name, temperature=0)
    
        
    # { "product_info": RunnablePassthrough() } is same as lambda x: x
    # basically do not modify what the user entered, pass into the key product_info
    summarise_chain = { "product_info": RunnablePassthrough() } | prompt | model | StrOutputParser()
    summary = summarise_chain.invoke(product_info)
    return summary

# %%
max_products_per_category = 20

product_data.keys()
# Out:
# dict_keys(['MEN_FASHION_WITH_REVIEWS', 'SKIN_CARE_WITH_REVIEWS', 'WOMEN_FASHION_NO_REVIEWS'])

# %% [markdown]
# ### Men Fashion

# %%
products = product_data['MEN_FASHION_WITH_REVIEWS']['products'][0:max_products_per_category]
combined_product_infos = [ ProductCombinedInformation(product=RAWProduct.model_validate(product)) for product in products ]

# Summarise Product Info = PCIS
product_info_summaries = [summarise_product_info(product_info.info(), model_name=product_summary_model_name) for product_info in combined_product_infos]


# for pis in product_info_summaries:
#     print(pis, "\n\n")

# %%
# Describe the Product Image = PID
image_prompt = f"""
Describe and summarise the characteristics of the product you are looking at. Start your response with: `The image is a product ... `. Return back plain text no markdown.
"""
product_image_descriptions = [describe_image(encode_image(image_path=product_info.image_path()), prompt=image_prompt, model_name=image_description_model_name) for product_info in combined_product_infos ]

for index, pid in enumerate(product_image_descriptions):
    print(index, pid, "\n\n")
# Out:
# 0  The image is a product display showcasing three different color variants of what appears to be a sports shoe.
#
#
# 1  The image is a product photo of a long-sleeve flannel shirt with a button-up front. It has two pockets on the chest, suggesting a practical design for carrying small items or for use in work environments. The shirt appears to have a casual yet functional style, suitable for both work and leisure activities.
#
#
# 2  The image is a product display showcasing several pairs of men's underwear. There are three pairs visible in the image, all with the same branding: "CALVIN KLEIN". Each pair features a waistband with the text "CALVIN KLEIN" and the style appears to be a boxer brief. The colors of the underwear vary; one is black, another is dark grey, and the third is navy blue. The design suggests a classic and recognized brand in casual wear.
#
#
# 3  The image is a product advertisement showcasing a set of socks. These socks feature a design that resembles the appearance of a credit card or banknote, with visible embossed patterns and text, including what appears to be a brand name "VYEN" prominently displayed. There are five pairs of these socks arranged vertically, each pair exhibiting a slightly different color combination: black with white text, gray with black text, red with black text, blue with white text, and white with black text. The socks have a ribbed texture and are presented against a neutral background that does not distract from the products.
#
#
# 4  The image is a product advertisement showcasing a pair of black dress shoes with white soles. They appear to be men's shoes, possibly from the brand Nike, as indicated by the logo on the side. The design includes laces and a prominent red tag attached to one shoe, which may suggest some special feature or branding. The overall style is formal, suggesting that these shoes could be worn for business or formal occasions.
#
#
# 5  The image is a product display of four pairs of black socks with different designs and patterns.
#
#
# 6  The image is a product of an item of clothing, specifically a grey sweatshirt or hoodie. It features the word "ESSENTIALS" printed on the front in white capital letters. The hoodie appears to be casual wear and has long sleeves, a kangaroo pocket on the left chest area, and a hood for added functionality.
#
#
# 7  The image is a product advertisement featuring a single black athletic shoe. This shoe appears to be designed for running or casual sportswear, as indicated by the cushioned sole and breathable fabric in the upper part of the shoe. The design includes laces, a toe cap, and what seems to be an integrated shoelace cover. On the side of the shoe is the Nike Swoosh logo, suggesting that this is a Nike product. The background of the image is plain white, highlighting the shoe without any distractions.
#
#
# 8  The image is a product advertisement for a Ravel brand watch. It's a close-up shot of the watch, showcasing its black leather strap and silver metal case with a white dial. The watch face features multiple dials, including what appears to be a date window at 3 o'clock, a small seconds subdial, and three additional dials for other functions. The hands of the watch are also silver, matching the overall metallic appearance of the timepiece. The brand name "Ravel" is visible on the face of the watch above the hour mark. The strap appears to be stitched with a contrasting thread, possibly white or light gray. The image is designed to present the watch in an appealing manner, emphasizing its design and functionality.
#
#
# 9  The image is a product advertisement showcasing a pair of athletic sneakers. It features a variety of shoe designs, each with different color combinations and styles. There are at least six images displaying the shoes from different angles and lighting conditions to highlight their design details and colors. Each image is a separate photograph within the collage, providing a comprehensive view of the product's appearance and potential variations in style or color scheme.
#
#
# 10  The image is a product advertisement featuring a pair of glasses. The glasses have a distinctive design, with the arms appearing to be folded inwards rather than outwards, creating an unusual and possibly artistic appearance. This unique design feature suggests that the glasses may have been engineered to minimize their footprint when not in use. They also seem to incorporate some level of smart technology or a high-tech aesthetic, as indicated by the visible electronic components on the arms. The frame of the glasses has a sleek and modern look, with what appears to be a glossy finish. Overall, the product is presented as a fashionable accessory that combines style with potential functionality.
#
#
# 11  The image is a product display of a pair of sunglasses.
#
#
# 12  The image is a product advertisement featuring a man in the foreground wearing black pants with a white drawstring, and in the background, there is another pair of black pants displayed on a hanger. The pants appear to have an elastic waistband and are styled in a relaxed fit. They feature two pockets on the lower legs and a small zippered compartment above the back pocket. The material seems soft and comfortable, suggesting they might be sweatpants or casual trousers.
#
#
# 13  The image is a product advertisement featuring a person modeling athletic attire. It showcases a pair of black pants with the waistband pulled up to expose the midsection, and they appear to be made of a stretchy fabric. The person is also wearing a white tank top underneath the pants. The style suggests this could be leisure or sportswear designed for comfort and ease of movement. There are no visible texts or logos on the clothing that can provide brand information or additional product details.
#
#
# 14  The image is a product advertisement featuring a pair of men's pajamas. The pajamas are plaid with a pattern that includes shades of green, blue, and white on a dark background. They appear to be a long-legged style, suitable for sleepwear or lounging wear. The pajamas are displayed on mannequins in two different settings: one showing the pajamas from a front view and another from a back view. The advertisement does not contain any text or additional context to provide further details about the product.
#
#
# 15  The image is a product photo of a dark blue or black necktie.
#
#
# 16  The image is a product photo of a six-pack of black crew socks. These socks appear to have a ribbed texture and are likely intended for athletic or casual wear, as they are commonly used in pairs for everyday use. There are no visible logos or brands on the socks, and there are no additional accessories shown alongside them. The focus is solely on the socks themselves, presented in a way that suggests they are new and possibly on sale.
#
#
# 17  The image is a product advertisement featuring men's casual pants. The pants are dark blue, possibly black or navy, and they have a slim fit. They are shown on a mannequin with the pants being the focus of the image. The background is plain white, which makes the product stand out. There is no visible text providing additional information about the product in this view.
#
#
# 18  The image is a product advertisement featuring a person wearing dark-colored casual pants, which appear to be high-waisted with a slim fit. The pants have a zipper fly and two front pockets. They are displayed in a way that shows the side seam and waistband design. The person is also wearing a white shirt and black shoes, suggesting a smart-casual style. The background of the image is plain, emphasizing the product.
#
#
# 19  The image is a product advertisement featuring a pair of black, elastic-waist pants. These pants are designed for casual or smart casual wear and appear to be made from stretchable material. They are showcased on a mannequin who is also wearing a white long-sleeve shirt and dark sneakers. The mannequin is standing with one hand in the pocket of the pants, suggesting a relaxed stance that may appeal to potential buyers looking for comfortable yet stylish trousers.

# %%
product_info_summaries[2], product_image_descriptions[2]
# Out:
# ('Here is a concise summary of the product, optimized for retrieval:\n\n**Men Boxer Short Trunks Stretch Cotton Pack of 3**\n\n* **Product Details**: Calvin Klein boxer shorts with CK branding, designed for everyday wear and sports.\n* **Material Composition**: 95% Cotton, 5% Elastane (Spandex).\n* **Care Instructions**: Machine Washable.\n* **Key Features**:\n\t+ Comfortable fit due to stretchy fabric.\n\t+ Classic elastic waistband with logo.\n\t+ Soft and breathable cotton stretch material.\n* **Brand Information**: Calvin Klein lifestyle brand, known for minimalist aesthetics and timeless designs.\n* **Product Specifications**:\n\t+ Package Dimensions: 19.56 x 13.21 x 3.3 cm; 100 Grams.\n\t+ Date First Available: June 18, 2023.\n\t+ Manufacturer: Calvin Klein.\n\t+ Item Model Number: 0000U2662G.\n* **Customer Reviews**: 4.6 out of 5 stars (36,088 ratings).\n* **Price**: £28.0.\n\nThis summary includes the most important details about the product, making it easy to retrieve and compare with other products in the same category.',
#  ' The image is a product display showcasing several pairs of men\'s underwear. There are three pairs visible in the image, all with the same branding: "CALVIN KLEIN". Each pair features a waistband with the text "CALVIN KLEIN" and the style appears to be a boxer brief. The colors of the underwear vary; one is black, another is dark grey, and the third is navy blue. The design suggests a classic and recognized brand in casual wear. ')

# %% [markdown]
# ### Create the Multi Vector Retriever

# %%
# Vector Store for Document Embeddings
from langchain_chroma import Chroma
from langchain_experimental.open_clip import OpenCLIPEmbeddings
from langchain_openai import OpenAIEmbeddings

from langchain_community.embeddings.ollama import OllamaEmbeddings
from langchain.embeddings import CacheBackedEmbeddings
from langchain.storage import LocalFileStore

from chromadb.errors import InvalidDimensionException

# OpenCLIP: https://github.com/mlfoundations/open_clip
# Larger and more performant
# model_name = "ViT-g-14"
# checkpoint = "laion2b_s34b_b88k"

# # Smaller less performant
# model_name = "ViT-B-32"
# checkpoint = "laion2b_s34b_b79k"

# # Default
model_name = "ViT-H-14"
checkpoint = "laion2b_s32b_b79k"

text_embedding_model_name = "nomic-embed-text"

# for nomic-embed, embed_instruction is `search_document` to embed documents for RAG and `search_query` to embed the question
underlying_embedding = OllamaEmbeddings(model=text_embedding_model_name, embed_instruction="search_document", query_instruction="search_query")
underlying_embedding = OpenAIEmbeddings()
reset_collection = True

store = LocalFileStore("./embeddings-cache")

cached_embedder = CacheBackedEmbeddings.from_bytes_store(
    underlying_embeddings=underlying_embedding, document_embedding_cache=store, namespace=underlying_embedding.model
)


collection_name = f"fashion_store_mrag_v_{underlying_embedding.model}"
try:
    products_vectorstore = Chroma(
        collection_name=collection_name ,
        embedding_function=cached_embedder,
        # https://docs.trychroma.com/guides#changing-the-distance-function
        # Cosine, 1 means most similar, 0 means orthogonal, -1 means opposite
        collection_metadata={"hnsw:space": "cosine"}, # l2 is the default
        # embedding_function=OpenCLIPEmbeddings(model=None, preprocess=None, tokenizer=None, model_name=model_name, checkpoint=checkpoint)
    )
except InvalidDimensionException:
    Chroma().delete_collection()
    products_vectorstore = Chroma(
        collection_name=collection_name ,
        embedding_function=cached_embedder,
        collection_metadata={"hnsw:space": "cosine"}, # l2 is the default
    )
    
if reset_collection:
    products_vectorstore.reset_collection()

# %%
import json
import os
from pathlib import Path

images_path = "../initial-training-sets/datasets/images"

from langchain.retrievers.multi_vector import MultiVectorRetriever, SearchType
from langchain.storage import InMemoryStore
from langchain_core.documents import Document

from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=4000)

n_docs_to_retrieve = 4
relevant_threshold_score = 0.8

def create_multi_vector_retriever(
        embeddings_vectorsotre, 
        product_combined_info_summaries: List[str],  # PCIS -> Product Combined Info Summary
        product_image_descriptions: List[str],  # PID
        product_combined_infos: List[ProductCombinedInformation] # PCI objects
    ):
    
    # Initialise the document storage layer
    document_store = InMemoryStore()
    id_key = "product_id"
    
    retriever = MultiVectorRetriever(
        vectorstore=embeddings_vectorsotre,
        docstore=document_store,
        id_key=id_key,
        search_type=SearchType.similarity_score_threshold,
        search_kwargs={
            # below works only for similarity_score_threshold search_type
            "score_threshold": relevant_threshold_score, # close to 0 means most dissimilar, 1 means most similar
            "k": n_docs_to_retrieve
        }
    )
    
    # Helper function to add documents into the vector and the doument store
    def add_documents(retriever: MultiVectorRetriever, summary_to_embeds: List[str], combined_product_infos: List[ProductCombinedInformation]):
        product_ids=[ str(product_info_obj.product.id) for product_info_obj in combined_product_infos ]
        data = list(zip(product_ids, summary_to_embeds, combined_product_infos))
               
        docs = []
        parent_docs_contents = []
        
        for single_item in data:
            product_id, content_to_embed, product_info = single_item
            for content_chunk in splitter.split_text(content_to_embed):
                docs.append(Document(
                    page_content=content_chunk,
                    metadata={
                        id_key: product_id,
                        "id": product_id,
                        "name": product_info.product.name,
                        "product_asin": product_info.product.product_asin
                    }
                ))
                parent_docs_contents.append(
                    Document(
                        page_content=product_info.info(),
                        metadata={
                            id_key: product_info.product.id,
                            "id": product_info.product.id,
                            "name": product_info.product.name,
                            "product_asin": product_info.product.product_asin
                        }
                    ) 
                )
        
        assert len(docs) == len(parent_docs_contents)
        
        retriever.vectorstore.add_documents(docs)
        retriever.docstore.mset(list(zip(product_ids, parent_docs_contents)))
        
        return retriever
    
    if product_combined_info_summaries:
        add_documents(
            retriever=retriever,
            summary_to_embeds=product_combined_info_summaries,
            combined_product_infos=product_combined_infos
        )
        
    if product_image_descriptions:
        add_documents(
            retriever=retriever,
            summary_to_embeds=product_image_descriptions,
            combined_product_infos=product_combined_infos
        )
        
    return retriever

# %%
retriever = create_multi_vector_retriever(
    embeddings_vectorsotre=products_vectorstore, 
    product_combined_info_summaries=product_info_summaries, 
    product_image_descriptions=product_image_descriptions,
    product_combined_infos=combined_product_infos, 
)

retriever_query = "I dark coloured casual pants" # description only in the image
retriever_query = "high tech glasses" # description only in the image
retriever_query = "queen" # description only in the image
retriever_query = "pants with zipper fly" # description only in the image

docs = retriever.invoke(retriever_query)

for doc in docs:
    print(doc.page_content)
    

print("----")
# retriever.vectorstore.similarity_search_with_relevance_scores(retriever_query, k=3)
docs = retriever.vectorstore.similarity_search_with_relevance_scores(retriever_query, k=n_docs_to_retrieve)
for doc, score in docs:
    print(score, score >= relevant_threshold_score , " - " , doc.metadata.get('product_asin'), doc.page_content)
# Out:
# Product ID: 696b7628-954d-4303-b773-c81cd0ad687e
# Product Name: for Men, Slim Fit, Stretch - Comfortable and Modern Mens Trousers with Stretch for Suits, Business, Casual, Golf, Office
# Product Description: Product details     Material composition     3% Elastane (stretch), 75% Viscose, 22% Polyester       Care instructions     Machine Wash       Closure type     Zipper       Rise style     Mid Rise      About this item   STYLISH COMFORTABLE AFFORDABLE: Our chinos trousers men are trousers with a stylish look and great functionality so you can enjoy excellent comfort when wearing them. These black pants men feature a moisture-wicking fabric   EXCEPTIONAL COMFORT: In contrast to ordinary mens chinos our trousers men are equipped with a comfortable stretch effect so the wearer experiences optimal comfort when wearing these mens stretch trousers   PANTS FOR EVERY SITUATION: With our stylish and comfortable mens linen trousers you always have high wearing comfort and optimal mobility whether at work chilling or golfing. These mens chino trousers offer a sleek and modern appearance   HIGH QUALITY AND CHEAP AT THE SAME TIME; High quality doesn't always have to cost a lot of money. Our linen trousers mens are clear proof of this. Crafted with meticulous attention to detail our men's trousers are designed for enduring quality   THE PERFECT MATERIAL COMPOSITION: These mens casual trousers are made from 3% elastane (stretch) 75% viscose and 22% polyester. These chinos men are fully machine washable   See less About this item    Product details    Package Dimensions                                     ‏                                         :                                     ‎                                  39.9 x 28.6 x 3.4 cm; 510 Grams   Date First Available                                     ‏                                         :                                     ‎                                  22 July 2022   Manufacturer                                     ‏                                         :                                     ‎                                  TeeRetail ApS   ASIN                                     ‏                                         :                                     ‎                                  B09ZDY291M   Department                                     ‏                                         :                                     ‎                                  Men's       Best Sellers Rank:  4,035 in Fashion (See Top 100 in Fashion)   38 in Men's Trousers       Customer reviews:         4.1  4.1 out of 5 stars         1,192 ratings               Product Description                        Video Player is loading.Play VideoPlayMuteCurrent Time 0:00/Duration -:-Loaded: 0%Stream Type LIVESeek to live, currently behind liveLIVERemaining Time -0:00 1xPlayback RateChaptersChaptersDescriptionsdescriptions off, selectedCaptionsCaptions off, selectedAudio TrackFullscreenThis is a modal window.The media could not be loaded, either because the server or network failed or because the format is not supported.
# Product Asin: B09HXLDG5B
# Overall Ratings 4.1
# Total Customers that rated: 1188
# Pric: £44.99
#
# Product ID: 34e47362-144b-470c-8c96-8ccbf9e2ea8e
# Product Name: Mens Joggers Tracksuit Bottoms Men for Running Sports Lounge with Zip Pockets Elasticated Waist
# Product Description: Product details     Material composition     70% Cotton, 25% Polyester, 5% Elastane       Care instructions     Hand Wash or Machine Wash       Closure type     Drawstring       Pocket style     Zipper Pocket      About this item   Safe Zip Pockets: Mens Joggers have 2 handy zip pockets each side, which provide safe space for storing for mobile phones,keys,wallets,etc.   Mens Joggers Bottoms: are ideal for home, walk, camping, jogging, running, training, sports and other activieties.   Comfortable Cut-Out: These tracksuit bottoms mens with elasticated waist and adjustable drawstring are reasonably smart looking,and also fit nicely.They feature a stylish and practical design and are ideal for modern,ative men.   Skin-friendly Fabric: 70% Cotton, 25% Polyester, 5% Elastane.Mens Tracksuit Bottom are hard wearing and allow a certain amount of stretch,so they are very comfortable to wear.   Regarding the size, please kindly refer to the size table showed on the picture,and if you like loose jogging bottoms men, please go one size up. Any questions about our HCSS sweatpants,welcome to contact us.   See less About this item    Product details    Product Dimensions                                     ‏                                         :                                     ‎                                  32 x 22 x 2 cm; 408 Grams   Date First Available                                     ‏                                         :                                     ‎                                  20 May 2023   Manufacturer                                     ‏                                         :                                     ‎                                  HCSS   ASIN                                     ‏                                         :                                     ‎                                  B0C5TJDNKD   Department                                     ‏                                         :                                     ‎                                  Men's       Best Sellers Rank:  2,453 in Fashion (See Top 100 in Fashion)   13 in Men's Sweatpants       Customer reviews:         4.2  4.2 out of 5 stars         863 ratings               Product Description             HCSS Mens Joggers    Tracksuit Bottoms Mens   HCSS is a clothing company specializing in men's clothing design, research and development, production and sales. So please rest assured to buy our products.   LESS IS MORE !   This kind of joggers for men is a classic basic style. Simple colors give it versatile and practical functions to meet the needs of daily life activities. Reasonable tailoring makes it comfortable and natural to wear. If you don't know what to choose, our HCSS jogging pants will be  a good recommendation. As the saying goes, less is more.       Suitable for Many Occasions    Mens joggers are suitable for indoor and outdoor activities, such as jogging, running, exercise, sports, hiking,  home, picnic,  shopping and so on.   We HCSS brand was established in 2019. Although we were young, we quickly attracted many fans due to our high-quality clothing and innovative design.       UK Size Chart    Jogging Bottoms Men   Attention: Our men tracksuit bottoms are smaller than normal size, if you want to be loose, please choose pants that are one size larger.        Strong Points of Jogging Bottoms Men                              Slim fit but not tight   Slim fit and elastic & skin friendly  fabrics make these mens tracksuit bottom not only able to show the lines of the body but also comfortable to wear.       Mens Joggers with Zip pockets   There is a zip pocket on both sides of the sports pants, which can not only hold mobile phones, keys, cards and other items, but also won't fall easily.       Thoughtful drawstring   The waistband is designed to be elastic, coupled with a practical drawcord, which will have a great tolerance for the body and can well adapt to different fig ...
# Product Asin: B09C5FHR99
# Overall Ratings 4.2
# Total Customers that rated: 863
# Pric: £23.98
#
# ----
# 0.8606507182121277 True  -  B09HXLDG5B The image is a product advertisement featuring a person wearing dark-colored casual pants, which appear to be high-waisted with a slim fit. The pants have a zipper fly and two front pockets. They are displayed in a way that shows the side seam and waistband design. The person is also wearing a white shirt and black shoes, suggesting a smart-casual style. The background of the image is plain, emphasizing the product.
# 0.8475469946861267 True  -  B09C5FHR99 The image is a product advertisement featuring a man in the foreground wearing black pants with a white drawstring, and in the background, there is another pair of black pants displayed on a hanger. The pants appear to have an elastic waistband and are styled in a relaxed fit. They feature two pockets on the lower legs and a small zippered compartment above the back pocket. The material seems soft and comfortable, suggesting they might be sweatpants or casual trousers.
# 0.8417893052101135 True  -  B09HXLDG5B The image is a product advertisement featuring a pair of black, elastic-waist pants. These pants are designed for casual or smart casual wear and appear to be made from stretchable material. They are showcased on a mannequin who is also wearing a white long-sleeve shirt and dark sneakers. The mannequin is standing with one hand in the pocket of the pants, suggesting a relaxed stance that may appeal to potential buyers looking for comfortable yet stylish trousers.
# 0.8234686851501465 True  -  B09C5FHR99 The image is a product advertisement featuring a person modeling athletic attire. It showcases a pair of black pants with the waistband pulled up to expose the midsection, and they appear to be made of a stretchy fabric. The person is also wearing a white tank top underneath the pants. The style suggests this could be leisure or sportswear designed for comfort and ease of movement. There are no visible texts or logos on the clothing that can provide brand information or additional product details.

# %% [markdown]
# ### Synthesize Answer / Pass docs to LLM

# %%
from langchain_community.chat_models.ollama import ChatOllama


model = ChatOllama(model="llama3.1", temperature=0, num_ctx=1024)
model = ChatOpenAI(model="gpt-4o", temperature=0)


from langchain.chains.combine_documents.stuff import create_stuff_documents_chain
from langchain.prompts.chat import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, SystemMessage
from langchain.chains.retrieval import create_retrieval_chain
from langchain.chains.history_aware_retriever import create_history_aware_retriever

# Retrieval Chain: summarise history + current query/input to fetch relevant documents
history_prompt = ChatPromptTemplate.from_messages(
    [
        MessagesPlaceholder(variable_name="chat_history"),
        SystemMessage(content="generate a search query to look up in order to get information relevant to the conversation."),
        ("user", "{input}"),
    ]
)
history_chain = create_history_aware_retriever(
  llm=model, retriever=retriever, prompt=history_prompt
)

# Answer Synthesising
system_message = """
                  You work as a stylish and Gen-Z customer assistance in a fashion store.
                  
                  Inventory Start
                  {context}
                  Inventory Ends
                  
                  Try to persuade the user to go ahead and click the buy button for one of these products. 
                  It will take them to an Amazon page where they can continue their purchase
                  
                  In situation where there are multiple products in the inventory, 
                  explain how each of them can be helpful
                  
                  There are times the inventory will be empty, assure the user 
                  we will get the product that would match their query if it is something a 
                  fashion store can provide as a service.
                """
prompt = ChatPromptTemplate.from_messages([
    ("system", system_message ),
    MessagesPlaceholder(variable_name="chat_history"), # empty for now
    ("human", "{input}" ),
])

# a chain that allows us pass a list of docs to a model
stuff_documents_and_prompts_chain = create_stuff_documents_chain(llm=model, prompt=prompt)

# a chain to use the retriever we have to retireve the relevant docs and then pass them to the chain that has the llm+prompt
chain = create_retrieval_chain(
  retriever=history_chain, # We can either pass a retriever or a chain
  combine_docs_chain=stuff_documents_and_prompts_chain
)

# user_question = "The summer is here, what item can I buy to add to my accessory? Glasses, hats etc"
user_question = "The summer is here, what item can I buy to add to my accessory?"

# The documents fetched does not meet our threshold for relevance scores, so it wil be empty. Inventory is empty!
docs = retriever.vectorstore.similarity_search_with_relevance_scores(user_question, k=n_docs_to_retrieve)
for doc, score in docs:
    print(score, score >= relevant_threshold_score , " - " , doc.metadata.get('product_asin'), doc.page_content)


chain.invoke({"input": user_question, "chat_history": []})
# Out:
# 0.8050183653831482 True  -  B01B1D12B0 The image is a product display of a pair of sunglasses.
# 0.7729806303977966 False  -  B0BRNFVSCF The image is a product of an item of clothing, specifically a grey sweatshirt or hoodie. It features the word "ESSENTIALS" printed on the front in white capital letters. The hoodie appears to be casual wear and has long sleeves, a kangaroo pocket on the left chest area, and a hood for added functionality.
# 0.7648344039916992 False  -  B09HXLDG5B The image is a product advertisement featuring a person wearing dark-colored casual pants, which appear to be high-waisted with a slim fit. The pants have a zipper fly and two front pockets. They are displayed in a way that shows the side seam and waistband design. The person is also wearing a white shirt and black shoes, suggesting a smart-casual style. The background of the image is plain, emphasizing the product.
# 0.7647953629493713 False  -  B09HXLDG5B The image is a product advertisement featuring a pair of black, elastic-waist pants. These pants are designed for casual or smart casual wear and appear to be made from stretchable material. They are showcased on a mannequin who is also wearing a white long-sleeve shirt and dark sneakers. The mannequin is standing with one hand in the pocket of the pants, suggesting a relaxed stance that may appeal to potential buyers looking for comfortable yet stylish trousers.
# {'input': 'The summer is here, what item can I buy to add to my accessory?',
#  'chat_history': [],
#  'context': [Document(metadata={'product_id': UUID('96f87d3b-5202-4ada-8b60-a1326719302f'), 'id': UUID('96f87d3b-5202-4ada-8b60-a1326719302f'), 'name': "Men's Retro Driving Polarized Sunglasses Man Al-Mg Metal Frame Ultra Light UV400 CAT 3 CE", 'product_asin': 'B01B1D12B0'}, page_content="Product ID: 96f87d3b-5202-4ada-8b60-a1326719302f \nProduct Name: Men's Retro Driving Polarized Sunglasses Man Al-Mg Metal Frame Ultra Light UV400 CAT 3 CE \nProduct Description: Product details     Care instructions     Far away from seawater or corrosive drugs,otherwise lens coating got damage.       Country of origin     Hong Kong      About this item   WHY CHOOSE US? -【Say goodbye to poor Polarized Lens】Low-quality lenses can cause lasting harm to your eyes. Our mens sun glasses are committed to using premium materials. Presently, ATTCL PrismX HD Polarized Lens incorporates an innovative PrismX layer, elevating standard TAC Polarized Lens for 100% UV400 protection coating and enduring high-definition clarity.   WHY CHOOSE US? -【Experience enhanced eye protection】- While standard UV400 lenses offer basic defense, our Men's Sunglasses UV400 lenses employ a dual 'substrate + coating' defense, effectively blocking UV rays up to 400 nanometers. This significantly reduces the risk of visual fatigue and skin aging due to UV exposure, ensuring enhanced eye safety.   WHY CHOOSE US? -【Aerospace-grade AL-MG Frame】- ATTCL Polarized Sunglasses men are stronger, ultra-light, ultra-hard, flexible, corrosion-resistant. 27% lighter than steel frame, stronger than TR90, premium Than plastic; All make this mens sunglasses polarized Ideal for Beach, Driving, Fishing, Golfing, Travel, and more.   WHY CHOOSE US? -【Amazon Gifts Options & Premium Package】- ATTCL Mens Sunglasses, Great Gift for Husband, Father, Son. including a Vintage Leather Case, gift box, microfiber pouch, cleaning cloth, and polarization test card. Thoughtfully curated for a complete gifting experience!   WHY CHOOSE US? -【24-hour Fast Response After-sales Support】- Your satisfaction matters! All ATTCL Driving Sunglasses come with a 30-Day No-Reason Return Guarantee and a Lifetime Frame Warranty. Easy to contact - Click our name below and hit 'Ask A Question' to reach Us.   See less About this item    Product details    Package Dimensions                                     \u200f                                         :                                     \u200e                                  16.5 x 6.4 x 5 cm; 100 Grams   Date First Available                                     \u200f                                         :                                     \u200e                                  11 Jun. 2018   Manufacturer                                     \u200f                                         :                                     \u200e                                  ATTCL   Item model number                                     \u200f                                         :                                     \u200e                                  AT8587   ASIN                                     \u200f                                         :                                     \u200e                                  B07DNQXP9G   Department                                     \u200f                                         :                                     \u200e                                  Men's       Best Sellers Rank:  1,546 in Fashion (See Top 100 in Fashion)   8 in Men's Sunglasses       Customer reviews:         4.3  4.3 out of 5 stars         13,906 ratings               Product Description                                                                                               The Most Pick                                               Top 1 sunglasses                                               Mens sunglasses 8188                                               Sunglasses man 6560                                               Sport sunglasses ...
#  'answer': 'Hey there! 🌞 Summer is the perfect time to elevate your accessory game, and I\'ve got just the thing for you. Check out our **Men\'s Retro Driving Polarized Sunglasses**! These aren\'t just any sunglasses; they\'re a blend of style, comfort, and top-notch eye protection.\n\n### Why You\'ll Love Them:\n1. **Premium Polarized Lenses**: Say goodbye to glare and hello to crystal-clear vision. The PrismX HD Polarized Lens offers 100% UV400 protection, ensuring your eyes are safe from harmful rays.\n2. **Aerospace-Grade Frame**: Made from AL-MG metal, these frames are ultra-light, super strong, and corrosion-resistant. Perfect for all your summer activities, whether it\'s hitting the beach, driving, or golfing.\n3. **Complete Package**: Comes with a vintage leather case, gift box, microfiber pouch, cleaning cloth, and a polarization test card. It\'s not just a purchase; it\'s an experience.\n4. **Great Gift Idea**: Looking for a gift for someone special? These sunglasses make an excellent gift for husbands, fathers, or sons.\n5. **Top-Rated**: With a 4.3 out of 5 stars rating from over 13,900 reviews, you know you\'re getting a quality product.\n\n### Special Features:\n- **Enhanced Eye Protection**: Dual \'substrate + coating\' defense effectively blocks UV rays up to 400 nanometers, reducing visual fatigue and skin aging.\n- **Fast Response After-Sales Support**: Enjoy a 30-Day No-Reason Return Guarantee and a Lifetime Frame Warranty.\n\n### Price:\n- **£27.00** – A small price to pay for such high-quality and stylish sunglasses.\n\nReady to upgrade your summer look? Click the "Add to Basket" button and head over to Amazon to complete your purchase. Trust me, you won\'t regret it! 🌴😎\n\n[Add To Basket](#)\n\nIf you have any other questions or need more recommendations, feel free to ask!'}

# %% [markdown]
# #### Thoughts on improving our Retriever
#
# In a situation with the question below, we will need to introduce a multi-query to ask the questions in different ways we can have more products to
#
# Question: "The summer is here, what item can I buy to add to my accessory?"
#
# Adding hats and glasses will improve the answer as shown below

# %%
user_question = "The summer is here, what item can I buy to add to my accessory? Glasses, hats etc"

# The documents fetched does not meet our threshold for relevance scores, so it wil be empty. Inventory is empty!
docs = retriever.vectorstore.similarity_search_with_relevance_scores(user_question, k=n_docs_to_retrieve)
for doc, score in docs:
    print(score, score >= relevant_threshold_score , " - " , doc.metadata.get('product_asin'), doc.page_content)


chain.invoke({"input": user_question, "chat_history": []})
# Out:
# 0.8269434571266174 True  -  B01B1D12B0 The image is a product display of a pair of sunglasses.
# 0.7963172197341919 False  -  B01B1D12B0 The image is a product advertisement featuring a pair of glasses. The glasses have a distinctive design, with the arms appearing to be folded inwards rather than outwards, creating an unusual and possibly artistic appearance. This unique design feature suggests that the glasses may have been engineered to minimize their footprint when not in use. They also seem to incorporate some level of smart technology or a high-tech aesthetic, as indicated by the visible electronic components on the arms. The frame of the glasses has a sleek and modern look, with what appears to be a glossy finish. Overall, the product is presented as a fashionable accessory that combines style with potential functionality.
# 0.7892106771469116 False  -  B01B1D12B0 **Men's Retro Driving Polarized Sunglasses**
#
# This product is a pair of men's retro driving polarized sunglasses made from ultra-lightweight AL-MG metal frame, providing excellent durability and corrosion resistance. The ATTCL PrismX HD Polarized Lens offers 100% UV400 protection coating and high-definition clarity, making it ideal for beach, driving, fishing, golfing, travel, and more.
#
# **Key Features:**
#
# * Ultra-lightweight AL-MG metal frame
# * ATTCL PrismX HD Polarized Lens with 100% UV400 protection coating
# * High-definition clarity
# * Dual 'substrate + coating' defense against UV rays
# * Corrosion-resistant and flexible
# * Ideal for beach, driving, fishing, golfing, travel, and more
#
# **Product Details:**
#
# * Product ID: 96f87d3b-5202-4ada-8b60-a1326719302f
# * Country of origin: Hong Kong
# * Package Dimensions: 16.5 x 6.4 x 5 cm; 100 Grams
# * Date First Available: June 11, 2018
#
# **Customer Reviews:**
#
# * Overall Ratings: 4.3/5 stars (based on 13,905 ratings)
# * Price: £27.0
# 0.7701979279518127 False  -  B01B1D12B0 **Men's Retro Driving Polarized Sunglasses Man Al-Mg Metal Frame Ultra Light UV400 CAT 3 CE**
#
# This product is a high-quality, polarized sunglasses designed for men, featuring an ultra-lightweight and corrosion-resistant AL-MG metal frame. The ATTCL PrismX HD Polarized Lens provides 100% UV400 protection coating and high-definition clarity, making it ideal for driving, beach activities, fishing, golfing, travel, and more.
#
# **Key Features:**
#
# * Ultra-lightweight and corrosion-resistant AL-MG metal frame
# * ATTCL PrismX HD Polarized Lens with 100% UV400 protection coating
# * Dual 'substrate + coating' defense against UV rays up to 400 nanometers
# * Ideal for driving, beach activities, fishing, golfing, travel, and more
# * Includes a vintage leather case, gift box, microfiber pouch, cleaning cloth, and polarization test card
# * 30-Day No-Reason Return Guarantee and Lifetime Frame Warranty
#
# **Product Details:**
#
# * Product ID: 96f87d3b-5202-4ada-8b60-a1326719302f
# * Country of origin: Hong Kong
# * Manufacturer: ATTCL
# * Item model number: AT8587
# * ASIN: B07DNQXP9G
# * Department: Men's
# * Best Sellers Rank: 1,546 in Fashion (See Top 100 in Fashion)
# * Customer reviews: 4.3 out of 5 stars (13,906 ratings)
# {'input': 'The summer is here, what item can I buy to add to my accessory? Glasses, hats etc',
#  'chat_history': [],
#  'context': [Document(metadata={'product_id': UUID('96f87d3b-5202-4ada-8b60-a1326719302f'), 'id': UUID('96f87d3b-5202-4ada-8b60-a1326719302f'), 'name': "Men's Retro Driving Polarized Sunglasses Man Al-Mg Metal Frame Ultra Light UV400 CAT 3 CE", 'product_asin': 'B01B1D12B0'}, page_content="Product ID: 96f87d3b-5202-4ada-8b60-a1326719302f \nProduct Name: Men's Retro Driving Polarized Sunglasses Man Al-Mg Metal Frame Ultra Light UV400 CAT 3 CE \nProduct Description: Product details     Care instructions     Far away from seawater or corrosive drugs,otherwise lens coating got damage.       Country of origin     Hong Kong      About this item   WHY CHOOSE US? -【Say goodbye to poor Polarized Lens】Low-quality lenses can cause lasting harm to your eyes. Our mens sun glasses are committed to using premium materials. Presently, ATTCL PrismX HD Polarized Lens incorporates an innovative PrismX layer, elevating standard TAC Polarized Lens for 100% UV400 protection coating and enduring high-definition clarity.   WHY CHOOSE US? -【Experience enhanced eye protection】- While standard UV400 lenses offer basic defense, our Men's Sunglasses UV400 lenses employ a dual 'substrate + coating' defense, effectively blocking UV rays up to 400 nanometers. This significantly reduces the risk of visual fatigue and skin aging due to UV exposure, ensuring enhanced eye safety.   WHY CHOOSE US? -【Aerospace-grade AL-MG Frame】- ATTCL Polarized Sunglasses men are stronger, ultra-light, ultra-hard, flexible, corrosion-resistant. 27% lighter than steel frame, stronger than TR90, premium Than plastic; All make this mens sunglasses polarized Ideal for Beach, Driving, Fishing, Golfing, Travel, and more.   WHY CHOOSE US? -【Amazon Gifts Options & Premium Package】- ATTCL Mens Sunglasses, Great Gift for Husband, Father, Son. including a Vintage Leather Case, gift box, microfiber pouch, cleaning cloth, and polarization test card. Thoughtfully curated for a complete gifting experience!   WHY CHOOSE US? -【24-hour Fast Response After-sales Support】- Your satisfaction matters! All ATTCL Driving Sunglasses come with a 30-Day No-Reason Return Guarantee and a Lifetime Frame Warranty. Easy to contact - Click our name below and hit 'Ask A Question' to reach Us.   See less About this item    Product details    Package Dimensions                                     \u200f                                         :                                     \u200e                                  16.5 x 6.4 x 5 cm; 100 Grams   Date First Available                                     \u200f                                         :                                     \u200e                                  11 Jun. 2018   Manufacturer                                     \u200f                                         :                                     \u200e                                  ATTCL   Item model number                                     \u200f                                         :                                     \u200e                                  AT8587   ASIN                                     \u200f                                         :                                     \u200e                                  B07DNQXP9G   Department                                     \u200f                                         :                                     \u200e                                  Men's       Best Sellers Rank:  1,546 in Fashion (See Top 100 in Fashion)   8 in Men's Sunglasses       Customer reviews:         4.3  4.3 out of 5 stars         13,906 ratings               Product Description                                                                                               The Most Pick                                               Top 1 sunglasses                                               Mens sunglasses 8188                                               Sunglasses man 6560                                               Sport sunglasses ...
#  'answer': 'Hey there! 🌞 Summer is the perfect time to elevate your accessory game, and I\'ve got just the thing for you! Check out our **Men\'s Retro Driving Polarized Sunglasses**. These aren\'t just any sunglasses; they\'re a blend of style, comfort, and top-notch eye protection. Here\'s why you should totally click that buy button:\n\n### Why These Sunglasses Are a Must-Have:\n1. **Premium Polarized Lenses**: Say goodbye to poor-quality lenses that can harm your eyes. Our PrismX HD Polarized Lens offers 100% UV400 protection, ensuring your eyes are safe from harmful rays.\n2. **Enhanced Eye Protection**: The dual \'substrate + coating\' defense effectively blocks UV rays up to 400 nanometers, reducing visual fatigue and skin aging.\n3. **Aerospace-Grade Frame**: Made from AL-MG metal, these frames are ultra-light, ultra-hard, and corrosion-resistant. Perfect for all your summer activities like beach outings, driving, fishing, and golfing.\n4. **Complete Gifting Experience**: Comes with a vintage leather case, gift box, microfiber pouch, cleaning cloth, and a polarization test card. It\'s a fantastic gift for yourself or a loved one!\n5. **Top-Rated**: With a 4.3 out of 5 stars rating from over 13,900 customers, you know you\'re getting a quality product.\n\n### Quick Specs:\n- **Package Dimensions**: 16.5 x 6.4 x 5 cm; 100 Grams\n- **Price**: £27.00\n- **Best Sellers Rank**: 8 in Men\'s Sunglasses\n\n### Customer Love:\n- **"These sunglasses are a game-changer! Perfect for driving and outdoor activities."**\n- **"Stylish and comfortable. The best sunglasses I\'ve ever owned."**\n\nSo, why wait? Click the buy button now and get ready to rock your summer look with these amazing sunglasses! 🌴😎\n\nIf you\'re looking for more options like hats or other accessories, let me know, and I\'ll find the perfect match for you!'}

# %% [markdown]
# #### What if we have multiple products?

# %%
user_question = "I need to buy new trousers! I need like three."

# The documents fetched does not meet our threshold for relevance scores, so it wil be empty. Inventory is empty!
docs = retriever.vectorstore.similarity_search_with_relevance_scores(user_question, k=n_docs_to_retrieve)
for doc, score in docs:
    print(score, score >= relevant_threshold_score , " - " , doc.metadata.get('product_asin'))


chain.invoke({"input": user_question, "chat_history": []})
# Out:
# 0.8132283091545105 True  -  B09C5FHR99
# 0.8108167052268982 True  -  B09HXLDG5B
# 0.8018320798873901 True  -  B09HXLDG5B
# 0.7988615036010742 False  -  B09HXLDG5B
# {'input': 'I need to buy new trousers! I need like three.',
#  'chat_history': [],
#  'context': [Document(metadata={'product_id': UUID('34e47362-144b-470c-8c96-8ccbf9e2ea8e'), 'id': UUID('34e47362-144b-470c-8c96-8ccbf9e2ea8e'), 'name': 'Mens Joggers Tracksuit Bottoms Men for Running Sports Lounge with Zip Pockets Elasticated Waist', 'product_asin': 'B09C5FHR99'}, page_content="Product ID: 34e47362-144b-470c-8c96-8ccbf9e2ea8e \nProduct Name: Mens Joggers Tracksuit Bottoms Men for Running Sports Lounge with Zip Pockets Elasticated Waist \nProduct Description: Product details     Material composition     70% Cotton, 25% Polyester, 5% Elastane       Care instructions     Hand Wash or Machine Wash       Closure type     Drawstring       Pocket style     Zipper Pocket      About this item   Safe Zip Pockets: Mens Joggers have 2 handy zip pockets each side, which provide safe space for storing for mobile phones,keys,wallets,etc.   Mens Joggers Bottoms: are ideal for home, walk, camping, jogging, running, training, sports and other activieties.   Comfortable Cut-Out: These tracksuit bottoms mens with elasticated waist and adjustable drawstring are reasonably smart looking,and also fit nicely.They feature a stylish and practical design and are ideal for modern,ative men.   Skin-friendly Fabric: 70% Cotton, 25% Polyester, 5% Elastane.Mens Tracksuit Bottom are hard wearing and allow a certain amount of stretch,so they are very comfortable to wear.   Regarding the size, please kindly refer to the size table showed on the picture,and if you like loose jogging bottoms men, please go one size up. Any questions about our HCSS sweatpants,welcome to contact us.   See less About this item    Product details    Product Dimensions                                     \u200f                                         :                                     \u200e                                  32 x 22 x 2 cm; 408 Grams   Date First Available                                     \u200f                                         :                                     \u200e                                  20 May 2023   Manufacturer                                     \u200f                                         :                                     \u200e                                  HCSS   ASIN                                     \u200f                                         :                                     \u200e                                  B0C5TJDNKD   Department                                     \u200f                                         :                                     \u200e                                  Men's       Best Sellers Rank:  2,453 in Fashion (See Top 100 in Fashion)   13 in Men's Sweatpants       Customer reviews:         4.2  4.2 out of 5 stars         863 ratings               Product Description             HCSS Mens Joggers    Tracksuit Bottoms Mens   HCSS is a clothing company specializing in men's clothing design, research and development, production and sales. So please rest assured to buy our products.   LESS IS MORE !   This kind of joggers for men is a classic basic style. Simple colors give it versatile and practical functions to meet the needs of daily life activities. Reasonable tailoring makes it comfortable and natural to wear. If you don't know what to choose, our HCSS jogging pants will be  a good recommendation. As the saying goes, less is more.       Suitable for Many Occasions    Mens joggers are suitable for indoor and outdoor activities, such as jogging, running, exercise, sports, hiking,  home, picnic,  shopping and so on.   We HCSS brand was established in 2019. Although we were young, we quickly attracted many fans due to our high-quality clothing and innovative design.       UK Size Chart    Jogging Bottoms Men   Attention: Our men tracksuit bottoms are smaller than normal size, if you want to be loose, please choose pants that are one size larger.        Strong Points of Jogging Bottoms Men                              Slim fit but not tight   Slim fit and elastic &  ...
#   Document(metadata={'product_id': UUID('696b7628-954d-4303-b773-c81cd0ad687e'), 'id': UUID('696b7628-954d-4303-b773-c81cd0ad687e'), 'name': 'for Men, Slim Fit, Stretch - Comfortable and Modern Mens Trousers with Stretch for Suits, Business, Casual, Golf, Office', 'product_asin': 'B09HXLDG5B'}, page_content="Product ID: 696b7628-954d-4303-b773-c81cd0ad687e \nProduct Name: for Men, Slim Fit, Stretch - Comfortable and Modern Mens Trousers with Stretch for Suits, Business, Casual, Golf, Office \nProduct Description: Product details     Material composition     3% Elastane (stretch), 75% Viscose, 22% Polyester       Care instructions     Machine Wash       Closure type     Zipper       Rise style     Mid Rise      About this item   STYLISH COMFORTABLE AFFORDABLE: Our chinos trousers men are trousers with a stylish look and great functionality so you can enjoy excellent comfort when wearing them. These black pants men feature a moisture-wicking fabric   EXCEPTIONAL COMFORT: In contrast to ordinary mens chinos our trousers men are equipped with a comfortable stretch effect so the wearer experiences optimal comfort when wearing these mens stretch trousers   PANTS FOR EVERY SITUATION: With our stylish and comfortable mens linen trousers you always have high wearing comfort and optimal mobility whether at work chilling or golfing. These mens chino trousers offer a sleek and modern appearance   HIGH QUALITY AND CHEAP AT THE SAME TIME; High quality doesn't always have to cost a lot of money. Our linen trousers mens are clear proof of this. Crafted with meticulous attention to detail our men's trousers are designed for enduring quality   THE PERFECT MATERIAL COMPOSITION: These mens casual trousers are made from 3% elastane (stretch) 75% viscose and 22% polyester. These chinos men are fully machine washable   See less About this item    Product details    Package Dimensions                                     \u200f                                         :                                     \u200e                                  39.9 x 28.6 x 3.4 cm; 510 Grams   Date First Available                                     \u200f                                         :                                     \u200e                                  22 July 2022   Manufacturer                                     \u200f                                         :                                     \u200e                                  TeeRetail ApS   ASIN                                     \u200f                                         :                                     \u200e                                  B09ZDY291M   Department                                     \u200f                                         :                                     \u200e                                  Men's       Best Sellers Rank:  4,035 in Fashion (See Top 100 in Fashion)   38 in Men's Trousers       Customer reviews:         4.1  4.1 out of 5 stars         1,192 ratings               Product Description                        Video Player is loading.Play VideoPlayMuteCurrent Time\xa00:00/Duration\xa0-:-Loaded: 0%Stream Type\xa0LIVESeek to live, currently behind liveLIVERemaining Time\xa0-0:00\xa01xPlayback RateChaptersChaptersDescriptionsdescriptions off, selectedCaptionsCaptions off, selectedAudio TrackFullscreenThis is a modal window.The media could not be loaded, either because the server or network failed or because the format is not supported. \nProduct Asin: B09HXLDG5B \nOverall Ratings 4.1 \nTotal Customers that rated: 1188 \nPric: £44.99 \n")],
#  'answer': "Hey there! You're in luck because we've got some fab options for you. Let me break it down:\n\n1. **HCSS Mens Joggers Tracksuit Bottoms**:\n   - **Why You'll Love Them**: These joggers are perfect for both lounging and active days. With a blend of cotton, polyester, and elastane, they offer comfort and a bit of stretch. Plus, the zip pockets are super handy for keeping your essentials safe.\n   - **Perfect For**: Running, sports, lounging at home, or even a casual day out.\n   - **Price**: £23.98\n\n2. **Slim Fit Stretch Trousers**:\n   - **Why You'll Love Them**: These trousers are all about style and comfort. Made with a mix of elastane, viscose, and polyester, they offer a sleek look with a bit of stretch for optimal comfort. They're versatile enough for work, casual outings, or even a round of golf.\n   - **Perfect For**: Office wear, business meetings, casual outings, or even golfing.\n   - **Price**: £44.99\n\nWhy not mix and match? Grab a pair of joggers for your active days and two pairs of the slim fit trousers for a more polished look. This way, you'll be set for any occasion!\n\nReady to upgrade your wardrobe? Just click the buy button and you'll be taken to Amazon to complete your purchase. Happy shopping! 🌟"}
